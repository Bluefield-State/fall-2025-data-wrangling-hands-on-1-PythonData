# %%
#
# ~~~~~~~~~~~~~~~~~~IMPORTANT~~~~~~~~~~~~~~~~~~
#
# run this code first to download instructions and support files. 
# You will not be able to complete the assignment without them.
# Instructions will be found in the README.md file in the support_files folder.

import os

if not os.path.exists("support_files"):
    # !git clone --depth 1 --filter=blob:none --sparse \
        https://github.com/Bluefield-State/fall-2025-data-wrangling-hands-on-1-PythonData.git repo

    # !cd repo && git sparse-checkout set support_files
    # !mv repo/support_files .
    # !rm -rf repo

# %%
import pandas as pd
import json

# Step 1: Data Loading


# Create DataFrame


# Step 2: Data Cleaning
# Check for missing values in the 'tz' column


# Remove records without a time zone


# Standardize time zone names by replacing empty strings with 'Unknown'


# Step 3: Data Wrangling
# Create a summary table that counts frequency of each time zone


# Create DataFrame from the summary table


# Display the cleaned and reshaped DataFrame


# Save the summary to a CSV file
